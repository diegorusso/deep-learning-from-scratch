# %% [markdown]
# <a href="https://colab.research.google.com/github/diegorusso/deep-learning-from-scratch/blob/master/01_introduction_to_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning
#
# Deep learning is just a small part of the bigger field of machine learning which itself is part of even bigger field which is Artificial Intelligence, shorter AI.
#
# ![ai-machine-learning-deep-learning-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Machine Learning: ability to learn without being explicitly programmed. More precisely ML is an optimization problem in a multidimensional space in order to minimise the value of some cost function.
#
# Deep learning is the usage of machine learning with deep neural networks which are a kind of neural networks.
# The following image shows how many different kinds neural networks exist. Overtime more and more types are created in order to solve different problems.
#
# ![sbrs2f4qkhg41.png](data:image/png;base64,...)

# %% [markdown]
# The complexity around deep learning comes from the structure and the quantity of the data rather than the algorithms used.
#
# Its success started around 2012 where its performance were outperforming other Ml existent algorithms. The main reasons are:
# * bigger datasets
# * faster hardware
#
# Deep learning algorithms can be applied to learn how raw input data is related to the desired output in contrast of going through data pre-processing steps to identify features and post-processing to formulate the the output.

# %% [markdown]
# # Supervised Learning
#
# ![ff897f322fed.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Supervised learning requires a labelled dataset: this means the dataset contains both the inputs and the expected outputs.
# A supervised algorithm learns to **predict** outputs from the inputs.
#
# In supervised learning there are 2 phases:
# * training: a set of samples are presented and the algorithm learns how to predict the output from the input
# * inference: the parameters of the model are frozen and new data input are presented; the algorithm tries to predict or **infer** the output
#
# The image below shows the differences between these two phases.
#
# It's worth noting that training and inference are often done on different hardware platform because computationally different.
#
# ![training-vs-inference-rwd.png.rendition.intel.web.480.270.png](data:image/png;base64,...)

# %% [markdown]
# # What's a (deep) neural network?
#
# An images is worth a thousand words. Look below:
#
# ![0*0mia7BQKjUAuXeqZ.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# This is a deep neaural network. The *magic* though happens inside every single circle.
#
# Let's see what happens inside a neuron.
#
# ![artificialneuron__1.gif](data:image/gif;base64,...)

# %% [markdown]
# Each unit or neuron in an artificial neural network is composed of two parts:
# * a linear function: weighted sum of the inputs plus a bias term (trainable parameters)
# * a non-linear activation function: sigmoid, logistic function, ReLU (rectified linear unit), etc...
#
# ![1*4ZEDRpFuCIpUjNgjDdT2Lg.png](data:image/png;base64,...)

# %% [markdown]
# ReLU has become popular as an activation functio because it often performs better than the sigmoid function in the context of deep learning: networks are several times faster to train.
#
# Softmax is a special case of activation function used at the outputs of a neural network.
#
# General form of a deep neural network:
# * input layer: simply feeds data into the network
# * hidden/output layer: it computes the weighted sum of its inputs and a non-linear activation function as its output
#
# A neural network is trained in a series of steps and each step consists of **two passes**:
# * **forward propagation**: it calculates the weighted sums and activation functions as the training data samples propagate from inputs to outputs
# * **back propagation**: it calculates gradients which is the gradient of the cost function with respect to each of the trainable parameters in the network whoch are mostly weights and biases. Gradients are calculated layer-by-layer starting at the outputs and working backward toward the inputs.
#
# There is one forward pass and one backward pass for each batch or mini-batch.
#
# Deep learning can only work if there is a way of calculating the gradients in order to incrementally improve the parameter values in each layer
#
# The gradient is calculated separately for each trainable parameter. As a rule-of-thumb, the back-propagation of gradients takes about twice as much computation as forward propagation. Gradient calculation requires that every function on the forward path is differentiable, which it will be.
